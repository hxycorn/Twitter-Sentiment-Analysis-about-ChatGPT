# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Put raw data together

# %%
#Load Raw Data

df_Dec_1 = pd.read_csv('Dataset/Twitter_Dec_1.csv')
df_Dec_2 = pd.read_csv('Dataset/Twitter_Dec_2.csv')
df_Dec_3 = pd.read_csv('Dataset/Twitter_Dec_3.csv')
df_Dec_4 = pd.read_csv('Dataset/Twitter_Dec_4.csv')
df_Dec_5 = pd.read_csv('Dataset/Twitter_Dec_5.csv')
df_Dec_6 = pd.read_csv('Dataset/Twitter_Dec_6.csv')
df_Jan_1 = pd.read_csv('Dataset/Twitter_Jan_1.csv')
df_Jan_2 = pd.read_csv('Dataset/Twitter_Jan_2.csv')
df_Jan_3 = pd.read_csv('Dataset/Twitter_Jan_3.csv', dtype = {0:object, 2:object})
df_Jan_4 = pd.read_csv('Dataset/Twitter_Jan_4.csv')
df_Jan_5 = pd.read_csv('Dataset/Twitter_Jan_5.csv')
df_Jan_6 = pd.read_csv('Dataset/Twitter_Jan_6.csv', dtype = {0:object, 2:object})
df_Jan_7 = pd.read_csv('Dataset/Twitter_Jan_7.csv')
df_Jan_8 = pd.read_csv('Dataset/Twitter_Jan_8.csv')
df_Jan_9 = pd.read_csv('Dataset/Twitter_Jan_9.csv')
df_Jan_10 = pd.read_csv('Dataset/Twitter_Jan_10.csv')

# %%
#Combine all data from December into a dataframe
df_Dec= pd.concat([df_Dec_1, df_Dec_2, df_Dec_3, df_Dec_4, df_Dec_5, df_Dec_6])
df_Jan = pd.concat([df_Jan_1, df_Jan_2, df_Jan_3,df_Jan_4, df_Jan_5, df_Jan_6,df_Jan_7,df_Jan_8,df_Jan_9,df_Jan_10])

# %%
df_Dec.shape, df_Jan.shape
# Out:
# ((511917, 9), (808919, 9))

# %%
#Remove duplicates
df_Dec = df_Dec.drop_duplicates()
df_Jan = df_Jan.drop_duplicates()
df_Dec.shape, df_Jan.shape
# Out:
# ((474572, 9), (780946, 9))

# %%
df_Dec = df_Dec.reset_index(drop=True)
df_Jan = df_Jan.reset_index(drop=True)

# %%
df_Dec.to_csv("Twitter_Dec_overall.csv", index=False)
df_Jan.to_csv("Twitter_Jan_overall.csv", index=False)

# %%
#Combine December and January Data together
df = pd.concat([df_Jan, df_Dec])

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#                 UserId       UserName Verified             Location  \
# 0  1620210123732828162  Erban_legend_    False          Chicago, IL
# 1  1620210123456270336        doomoog    False                  NaN
# 2  1620210110240034819      yanhaica1    False  Toronto, on, Canada
# 3  1620210048281776130       yasegumi    False                  NaN
# 4  1620210039570022401  datos_digital    False            Australia
#
#    Followers                                              Tweet  \
# 0      763.0  ChatGPT is basically the best unpaid intern to...
# 1       60.0  @jeffersonmorley @ChatGPT @OpenAI It pulled th...
# 2     1493.0  #ChatGPT is down for me since yesterday. Is it...
# 3      273.0  @GalorOded ChatGPT is literally the marriage o...
# 4     6385.0  ChatGPT Is Making Universities Rethink Plagiar...
#
#                    Timestamp  Retweeted Language
# 0  2023-01-30 23:59:30+00:00        NaN       en
# 1  2023-01-30 23:59:30+00:00        NaN       en
# 2  2023-01-30 23:59:26+00:00        NaN       en
# 3  2023-01-30 23:59:12+00:00        NaN       en
# 4  2023-01-30 23:59:10+00:00        NaN       en

# %% [markdown]
# ## Clean data for EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255518 entries, 0 to 1255517
# Data columns (total 9 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   UserId     1255518 non-null  object
#  1   UserName   1255514 non-null  object
#  2   Verified   1255509 non-null  object
#  3   Location   896379 non-null   object
#  4   Followers  1255507 non-null  float64
#  5   Tweet      1255508 non-null  object
#  6   Timestamp  1255501 non-null  object
#  7   Retweeted  0 non-null        float64
#  8   Language   1255501 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 86.2+ MB

# %%
#Drop the retweeted column
df.drop(columns='Retweeted', inplace = True)

# %%
#Divide the datetime columns into two separate columns
df['Timestamp']=pd.to_datetime(df['Timestamp'])
df['Date'] = df['Timestamp'].dt.date
df['Time_of_the_day'] = df['Timestamp'].dt.time

# %%
df[df['Timestamp'].isna()]
# Out:
#                                                    UserId  \
# 13609                                 1619958101599457282
# 13610   #Apollo #Apollos #protocol #Web3 #Metaverse #n...
# 41217                                 1620363648358318080
# 41218   #Python #Micropython #protocol #Web3 #Metavers...
# 52609                                 1620209645104287744
# 52610                                                /達成欲
# 52611                                                /戦略性
# 52612                                                /責任感
# 52613                                                 /内省
# 183158                              1620000000000000000.0
# 212835                                1618421900463722497
# 212836  #Cloudland #Labs #Cloudlandlab #protocol #Web3...
# 238867                                1618120600182226946
# 238868  #DiscoverAi #Discover #Ai #Web3 #Metaverse #NF...
# 519005                                1613988817949855744
# 519006                 Full video https://t.co/G2KL29OboH
# 519007  #ChatGPT #OpenAI #AI #Whisper #Dalle https://t...
#
#                          UserName  \
# 13609                     billnco
# 13610   2023-01-30 07:18:03+00:00
# 41217                     billnco
# 41218   2023-01-31 10:09:33+00:00
# 52609                  shupei1213
# 52610                         NaN
# 52611                         NaN
# 52612                         NaN
# 52613                        1336
# 183158                    billnco
# 212835                    billnco
# 212836  2023-01-26 01:33:44+00:00
# 238867                    billnco
# 238868  2023-01-25 05:36:28+00:00
# 519005               VictorGichun
# 519006                        NaN
# 519007  2023-01-13 19:58:15+00:00
#
#                                                  Verified  \
# 13609                                               False
# 13610                                                 NaN
# 41217                                               False
# 41218                                                 NaN
# 52609                                               False
# 52610                                                 NaN
# 52611                                                 NaN
# 52612                                                 NaN
# 52613   米バズフィードがChatGPTで記事作成へ\n\nここ数ヶ月、世の中へものすごいスピードで普...
# 183158                                              False
# 212835                                              False
# 212836                                                NaN
# 238867                                              False
# 238868                                                NaN
# 519005                                              False
# 519006                                                NaN
# 519007                                                NaN
#
#                          Location  Followers  \
# 13609                         NaN      127.0
# 13610                          en        NaN
# 41217                         NaN      127.0
# 41218                          en        NaN
# 52609                      SF┃学習欲        NaN
# 52610                         NaN        NaN
# 52611                         NaN        NaN
# 52612                         NaN        NaN
# 52613   2023-01-30 23:57:36+00:00        NaN
# 183158                        NaN      127.0
# 212835                        NaN      127.0
# 212836                         en        NaN
# 238867                        NaN      127.0
# 238868                         en        NaN
# 519005               San Jose, CA      567.0
# 519006                        NaN        NaN
# 519007                         en        NaN
#
#                                                     Tweet Timestamp Language  \
# 13609   https://t.co/0hPBv1VRTc is now available for sale       NaT      NaN
# 13610                                                 NaN       NaT      NaN
# 41217   https://t.co/nMQ0byRYaB is now available for sale       NaT      NaN
# 41218                                                 NaN       NaT      NaN
# 52609                                                 NaN       NaT      NaN
# 52610                                                 NaN       NaT      NaN
# 52611                                                 NaN       NaT      NaN
# 52612                                                 NaN       NaT      NaN
# 52613                                                  ja       NaT      NaN
# 183158  https://t.co/AaySmEnHIV is now available for sale       NaT      NaN
# 212835  https://t.co/Oltsr1ajcl is now available for sale       NaT      NaN
# 212836                                                NaN       NaT      NaN
# 238867  https://t.co/H7mplqY8Ys is now available for sale       NaT      NaN
# 238868                                                NaN       NaT      NaN
# 519005                  ChatGPT Writes Blog Posts. Watch.       NaT      NaN
# 519006                                                NaN       NaT      NaN
# 519007                                                NaN       NaT      NaN
#
#        Date Time_of_the_day
# 13609   NaT             NaT
# 13610   NaT             NaT
# 41217   NaT             NaT
# 41218   NaT             NaT
# 52609   NaT             NaT
# 52610   NaT             NaT
# 52611   NaT             NaT
# 52612   NaT             NaT
# 52613   NaT             NaT
# 183158  NaT             NaT
# 212835  NaT             NaT
# 212836  NaT             NaT
# 238867  NaT             NaT
# 238868  NaT             NaT
# 519005  NaT             NaT
# 519006  NaT             NaT
# 519007  NaT             NaT

# %%
#Remove missing values
df.dropna(subset=['Timestamp'], inplace = True)

# %%
#Drop the timestamp column
df = df.drop('Timestamp', axis=1)

# %%
df.reset_index(drop=True, inplace=True)

# %%
# Save data for EDA 
df.to_csv('Twitter_EDA.csv', index = False)

# %% [markdown]
# ## Data Preprocessing (english tweets only)

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
df_en = df[df['Language']=='en'].reset_index(drop=True)
df_en.shape
# Out:
# (832924, 9)

# %%
df_en = df_en.drop(columns = ['Language'])

# %%
#Remove URL from tweet text
df_en['Tweet'] = df_en['Tweet'].apply(lambda x: re.sub(r'http\S+', '',x))
#Remove mention (@user)
df_en['Tweet'] = df_en['Tweet'].apply(lambda x: re.sub(r'@\w+', '',x))
#All lowercases
df_en['Tweet'] = df_en['Tweet'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
#Remove Punctuation
df_en['Tweet_punc'] = df_en['Tweet'].apply(lambda x: re.sub('[^\w\s]', '', x))

# %%
#Replace 'chat gpt' with 'chatgpt'
df_en['Tweet_punc'] = df_en['Tweet_punc'].apply(lambda x: re.sub(r'chat gpt', 'chatgpt', x))

# %% [markdown]
# ### Remove stopwords

# %%
# install NLTK
#!pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hxyco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = stopwords.words('english')
df_en['Tweet_stop'] = df_en['Tweet_punc'].apply(lambda x: ' '.join(x for x in x.split() if x not in stop))

# %% [markdown]
# ### Tokenization

# %%
df_en['Tweet_tokenized'] = df_en['Tweet_stop'].apply(lambda x: re.split('\W+', x))

# %% [markdown]
# ### Lemmatization

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hxyco\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\hxyco\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
#define a function to map POS tags from treebank tag into wordnet tags
wnl = WordNetLemmatizer()
def get_wordnet(pos):
    if pos.startswith('N'): 
        return wordnet.NOUN
    elif pos.startswith('V'):
        return wordnet.VERB
    elif pos.startswith('J'):
        return wordnet.ADJ
    elif pos.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN     #default to noun if no match

    
# Define a function to tag and lemmatize a text string    
def lemmatizer(text):
    pos_tags = pos_tag(text)
    text = [wnl.lemmatize(word, pos = get_wordnet(pos)) for word, pos in pos_tags]
    return text

df_en['Tweet_lemmatized'] = df_en['Tweet_tokenized'].apply(lambda x: lemmatizer(x))

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm
#!pip install --upgrade dataclasses
#import spacy
# try spacy lemmatizer
###
def spacy_lemmatizer(text):
    # only need tagger, no need for parser and named entity recognizer, for faster implementation
    nlp = spacy.load('en_core_web_sm')
    allowed_tags=['NOUN', 'ADJ', 'VERB', 'ADV']
    doc = nlp(' '.join(text))
    lemmas = [token.lemma_ for token in doc]
    return lemmas
#df_en['Tweet_lemmatized_spacy'] = df_en['Tweet_tokenized'].apply(lambda x: spacy_lemmatizer(x))
###

# %%
df_en
# Out:
#               UserId       UserName  Verified              Location  \
# 0       1.620210e+18  Erban_legend_     False           Chicago, IL
# 1       1.620210e+18        doomoog     False                   NaN
# 2       1.620210e+18      yanhaica1     False   Toronto, on, Canada
# 3       1.620210e+18       yasegumi     False                   NaN
# 4       1.620210e+18  datos_digital     False             Australia
# ...              ...            ...       ...                   ...
# 832919  1.598105e+18  TimothyKassis     False            Boston, MA
# 832920  1.598105e+18       goodside     False          Richmond, VA
# 832921  1.598105e+18  lingzhong_eth     False                     ⛓
# 832922  1.598105e+18      bitchrate     False  kha\vivian \\ it\its
# 832923  1.598105e+18   akiraakimura     False          CDMX, Mexico
#
#         Followers                                              Tweet  \
# 0           763.0  chatgpt is basically the best unpaid intern to...
# 1            60.0                       it pulled this on me though:
# 2          1493.0  #chatgpt is down for me since yesterday. is it...
# 3           273.0  chatgpt is literally the marriage of madlibs t...
# 4          6385.0  chatgpt is making universities rethink plagiar...
# ...           ...                                                ...
# 832919      946.0  me: can you give me a sensationalist headline ...
# 832920    40296.0  openai’s new chatgpt seems to be trained again...
# 832921      167.0  i asked #chatgpt “is covid lockdown good or ba...
# 832922      251.0  chatgpt is really cool but man saying shit to ...
# 832923      192.0  ah chatgpt is the programming coach i needed. ...
#
#               Date Time_of_the_day  \
# 0       2023-01-30        23:59:30
# 1       2023-01-30        23:59:30
# 2       2023-01-30        23:59:26
# 3       2023-01-30        23:59:12
# 4       2023-01-30        23:59:10
# ...            ...             ...
# 832919  2022-12-01        00:02:43
# 832920  2022-12-01        00:01:53
# 832921  2022-12-01        00:01:15
# 832922  2022-12-01        00:00:28
# 832923  2022-12-01        00:00:01
#
#                                                Tweet_punc  \
# 0       chatgpt is basically the best unpaid intern to...
# 1                             it pulled this on me though
# 2       chatgpt is down for me since yesterday is it o...
# 3       chatgpt is literally the marriage of madlibs t...
# 4       chatgpt is making universities rethink plagiar...
# ...                                                   ...
# 832919  me can you give me a sensationalist headline s...
# 832920  openais new chatgpt seems to be trained agains...
# 832921  i asked chatgpt is covid lockdown good or bad ...
# 832922  chatgpt is really cool but man saying shit to ...
# 832923  ah chatgpt is the programming coach i needed  ...
#
#                                                Tweet_stop  \
# 0         chatgpt basically best unpaid intern ever exist
# 1                                           pulled though
# 2                                 chatgpt since yesterday
# 3       chatgpt literally marriage madlibs monte carlo...
# 4       chatgpt making universities rethink plagiarism...
# ...                                                   ...
# 832919  give sensationalist headline saying british ro...
# 832920  openais new chatgpt seems trained prompt injec...
# 832921  asked chatgpt covid lockdown good bad got back...
# 832922  chatgpt really cool man saying shit computer r...
# 832923  ah chatgpt programming coach needed asked buil...
#
#                                           Tweet_tokenized  \
# 0       [chatgpt, basically, best, unpaid, intern, eve...
# 1                                        [pulled, though]
# 2                             [chatgpt, since, yesterday]
# 3       [chatgpt, literally, marriage, madlibs, monte,...
# 4       [chatgpt, making, universities, rethink, plagi...
# ...                                                   ...
# 832919  [give, sensationalist, headline, saying, briti...
# 832920  [openais, new, chatgpt, seems, trained, prompt...
# 832921  [asked, chatgpt, covid, lockdown, good, bad, g...
# 832922  [chatgpt, really, cool, man, saying, shit, com...
# 832923  [ah, chatgpt, programming, coach, needed, aske...
#
#                                          Tweet_lemmatized
# 0       [chatgpt, basically, best, unpaid, intern, eve...
# 1                                          [pull, though]
# 2                             [chatgpt, since, yesterday]
# 3       [chatgpt, literally, marriage, madlibs, monte,...
# 4       [chatgpt, make, university, rethink, plagiaris...
# ...                                                   ...
# 832919  [give, sensationalist, headline, say, british,...
# 832920  [openais, new, chatgpt, seem, trained, prompt,...
# 832921  [ask, chatgpt, covid, lockdown, good, bad, get...
# 832922  [chatgpt, really, cool, man, say, shit, comput...
# 832923  [ah, chatgpt, program, coach, need, ask, build...
#
# [832924 rows x 12 columns]

# %%
#Remove columns not needed.
df_en_clean = df_en.drop(columns=['Tweet', 'Tweet_punc', 'Tweet_stop', 'Tweet_tokenized'])

# %%
df_en_clean['Tokens'] = df_en_clean['Tweet_lemmatized'].apply(lambda x: ' '.join(x))

# %%
df_en_clean.to_csv('Twitter_eng_clean.csv', index=False)

# %% [markdown]
# ### WordCloud

# %%
#!pip install wordcloud
#!pip install numpy matplotlib pillow
import numpy as np
import PIL.Image

# %%
from wordcloud import WordCloud
#prepare the long_string for wordcloud
long_string = ' '.join(list(df_en_clean['Tokens']))

# %%
def wordcloud_generate(string):
#load the mask image
    mask = np.array(PIL.Image.open('chatgpt3.png'))

    #define the wordcloud object
    wordcloud = WordCloud(scale =1,
                          mask = mask, 
                          background_color='white',
                          max_words=200,
                          contour_width=1,
                          contour_color='#74aa9c',
                         colormap='gist_earth',
                         stopwords=['chatgpt'])

    #generate the wordcloud
    wc = wordcloud.generate(string)

    #display the wordcloud
    fig = plt.figure(figsize=(12,8))
    plt.imshow(wc, interpolation = 'bilinear')
    plt.axis("off")
    plt.show()

# %%
wordcloud_generate(long_string)
