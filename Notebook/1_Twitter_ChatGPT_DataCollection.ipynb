# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\hxyco\appdata\local\temp\pip-req-build-w2nd_1u0
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit d60ce38b6a2d8aa55f29502f5517d47c1d9e4a5c
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for snscrape: filename=snscrape-0.5.0.20230114.dev9+gd60ce38-py3-none-any.whl size=70374 sha256=0966ca856b7821d69bbf304b80a07d1f2b4dfe49fd3795a024cb1d98cb537d04
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
query = 'ChatGPT since:2022-12-01 until:2023-01-31 '

limit = 500

# %%
query = 'ChatGPT until:2023-01-01'
limit = 100000
tweets_1 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_1) == limit:
        break
    else:
        tweets_1.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_1 = pd.DataFrame(tweets_1, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Date', 
                                     'Retweeted',                                
                                     'Language'])
df_1.head()
# Out:
# Unsupported unified_card type on tweet 1607896205178331138
#                 UserId       UserName  Verified                Location  \
# 0  1609338601955000320        ramacvr     False  Washington state , USA
# 1  1609338573056245761     shepsheplu     False                    Lyon
# 2  1609338561148628992      alt50code     False
# 3  1609338538226757632     cis_female     False                      sf
# 4  1609338488293363712  search_yordan     False
#
#    Followers                                              Tweet  \
# 0        232   From ChatGPT, neat stuff https://t.co/qjjUF2Z2m0
# 1        486  2023 predictions by #chatGPT. Nothing really s...
# 2          6  Mir scheint, dass die wirkliche Kraft von #Cha...
# 3       1171  chatgpt is being disassembled until it can onl...
# 4        206  I asked #ChatGPT to write a #NYE Joke for SEOs...
#
#                        Date Retweeted Language
# 0 2022-12-31 23:59:57+00:00      None       en
# ...

# %%
df_1 = pd.DataFrame(tweets_1, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_1
# Out:
#                     UserId         UserName  Verified                Location  \
# 0      1609338601955000320          ramacvr     False  Washington state , USA
# 1      1609338573056245761       shepsheplu     False                    Lyon
# 2      1609338561148628992        alt50code     False
# 3      1609338538226757632       cis_female     False                      sf
# 4      1609338488293363712    search_yordan     False
# ...                    ...              ...       ...                     ...
# 99995  1605589416625438722         it_audit     False
# 99996  1605589391912493058       cruickbook     False          in the Library
# 99997  1605589355283640320       AlamiThami     False                The Moon
# 99998  1605589331414028291  PlanasRodriguez     False           New York, USA
# 99999  1605589329996181505           KPKuhn     False            Ulm, Germany
#
#        Followers                                              Tweet  \
# ...

# %%
df_1.to_csv('Twitter_Dec_1.csv',index=False)

# %%
query = 'ChatGPT until:2022-12-22'
limit = 100000
tweets_2 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_2) == limit:
        break
    else:
        tweets_2.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_2 = pd.DataFrame(tweets_2, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_2
# Out:
#                     UserId         UserName  Verified  \
# 0      1605714712619933696       shimizgame     False
# 1      1605714646748368896         MSafe369     False
# 2      1605714612174757888         ToniKoqi     False
# 3      1605714559301361666      LifeProTips     False
# 4      1605714483317350400  ikinci_el_araba     False
# ...                    ...              ...       ...
# 99995  1602689449472757762  alabiadeolamike     False
# 99996  1602689447811842048  NobodysPerrfect     False
# 99997  1602689407752015873         djdoge69     False
# 99998  1602689405952606208   chris_lueders_     False
# 99999  1602689403369013248          nptacek     False
#
#                        Location  Followers  \
# 0                                      180
# 1                Italy 🇮🇹🇮🇹🇺🇸🇺🇸      13713
# 2                                       15
# 3                  In Your Head       8647
# 4                        Turkey        979
# ...                         ...        ...
# ...

# %%
df_2.to_csv('Twitter_Dec_2.csv',index=False)

# %%
query = 'ChatGPT until:2022-12-14'
limit = 100000
tweets_3 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_3) == limit:
        break
    else:
        tweets_3.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_3 = pd.DataFrame(tweets_3, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_3
# Out:
#                     UserId       UserName  Verified             Location  \
# 0      1602815617702055936        blogeye     False
# 1      1602815597162602496      meviusama     False  Birmingham, England
# 2      1602815546625380353      dave_rube     False
# 3      1602815488840671233  stevecrawfhtx     False          Houston, TX
# 4      1602815456716288001    1spread_das     False
# ...                    ...            ...       ...                  ...
# 99995  1600869233608790021       bryanbro     False
# 99996  1600869222619676672      AlvinWeb3     False
# 99997  1600869222506192896       rtvargas     False                Chile
# 99998  1600869213396238337       fschulze     False
# 99999  1600869213308342272      suzukenzz     False                   東京
#
#        Followers                                              Tweet  \
# 0            812  [ #Tistory ]안경사는 사람들에게 어떤 도움을 주고 있을까? chatGPT의...
# 1             28                              chatgpt penyelamat ku
# ...

# %%
df_3.to_csv('Twitter_Dec_3.csv',index=False)

# %%
query = 'ChatGPT until:2022-12-9'
limit = 100000
tweets_4 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_4) == limit:
        break
    else:
        tweets_4.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_4 = pd.DataFrame(tweets_4, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_4
# Out:
#                     UserId         UserName  Verified               Location  \
# 0      1601003674847019009         josekont     False
# 1      1601003595733774336      baytrojan03     False
# 2      1601003570698256385     DerekAshauer     False       Fort Collins, CO
# 3      1601003524191846400          cat_gpt     False
# 4      1601003520677019648           rez0__     False     hackerone.com/rez0
# ...                    ...              ...       ...                    ...
# 99995  1599732057034264576  AmintoreOficial     False  Mexico City & Caracas
# 99996  1599732021886349312         elsolros     False        något pronomen!
# 99997  1599732008283869185           r34b26     False                     日本
# 99998  1599731988730028032       mr_james_c     False        London, England
# 99999  1599731960305569792          lempiji     False                  日本 東京
#
#        Followers                                              Tweet  \
# ...

# %%
df_4.to_csv('Twitter_Dec_4.csv',index=False)

# %%
query = 'ChatGPT until:2022-12-6'
limit = 100000
tweets_5 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_5) == limit:
        break
    else:
        tweets_5.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_5 = pd.DataFrame(tweets_5, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_5
# Out:
# Unsupported unified_card type on tweet 1598662772761726976
#                     UserId         UserName  Verified         Location  \
# 0      1599916515167703042   curiousroberto     False
# 1      1599916509119201280  ProfessorKaos62     False        Pixlverse
# 2      1599916502811025408       PavelNosok     False  Valencia, Spain
# 3      1599916475363598344          jhulten     False      Seattle, WA
# 4      1599916443684020224  PoliticTriangle     False
# ...                    ...              ...       ...              ...
# 99995  1598305289039642624        edgarriba     False  Barcelona, CAT
# 99996  1598305277560123394   natsukigames55     False
# 99997  1598305276951552001         cio_zaki     False
# 99998  1598305242718023680           FQCme1     False
# 99999  1598305192407334912      hidekism_ok     False              クガネ
#
#        Followers                                              Tweet  \
# 0             29  AI is going to make bullshit jobs apparent.\n\...
# ...

# %%
df_5.to_csv('Twitter_Dec_5.csv',index=False)

# %%
query = 'ChatGPT until:2022-12-2 since:2022-12-1'
limit = 100000
tweets_6 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_6) == limit:
        break
    else:
        tweets_6.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_6 = pd.DataFrame(tweets_6, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_6
# Out:
#                     UserId       UserName  Verified               Location  \
# 0      1598466969141137408      askviable     False
# 1      1598466963466252288       mazen160     False  At a server near you.
# 2      1598466881761218560  ZoumanaCisse6     False               Bay area
# 3      1598466834776600576   papakichi111     False
# 4      1598466819777757184   palomairving     False        London, England
# ...                    ...            ...       ...                    ...
# 11912  1598105066753650688       goodside     False           Richmond, VA
# 11913  1598104931248242688    1024pixels1     False
# 11914  1598104905029660673  lingzhong_eth     False                      ⛓
# 11915  1598104707548987394      bitchrate     False   kha\vivian \\ it\its
# 11916  1598104597025153024   akiraakimura     False           CDMX, Mexico
#
#        Followers                                              Tweet  \
# ...

# %%
df_6.to_csv('Twitter_Dec_6.csv',index=False)

# %%
query = 'ChatGPT since:2023-01-01 until:2023-01-08'
limit = 100000
tweets_7 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_7) == limit:
        break
    else:
        tweets_7.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_7 = pd.DataFrame(tweets_7, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_7
# Out:
#                     UserId         UserName  Verified              Location  \
# 0      1611875323171463170   SchopenhauerOn     False
# 1      1611875295665029121  Blessedroyalty5     False  Somewhere Beautiful
# 2      1611875289004445696      The_mauteen     False        Lagos, Nigeria
# 3      1611875165062955009         arichika     False                 Japan
# 4      1611875164769189893  OurAmericanMind     False            Idaho, USA
# ...                    ...              ...       ...                   ...
# 99995  1609720151871471617       sajidmirza     False        United Kingdom
# 99996  1609720037535019008           0x7976     False
# 99997  1609719998225727488  JeanetteKStone1     False         San Diego, CA
# 99998  1609719887374458880       VisDigital     False
# 99999  1609719879191465987       TrishCarey     False              Portland
#
#        Followers                                              Tweet  \
# ...

# %%
df_7.to_csv('Twitter_Jan_10.csv',index=False)

# %%
query = 'ChatGPT since:2023-01-01 until:2023-01-03'
limit = 100000
tweets_8 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_8) == limit:
        break
    else:
        tweets_8.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_8 = pd.DataFrame(tweets_8, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_8
# Out:
#                     UserId        UserName  Verified                 Location  \
# 0      1610063379141648385     franlehmann     False  Buenos Aires, Argentina
# 1      1610063329409499137   sofiaterlesky     False
# 2      1610063322384306179      DreadBong0     False
# 3      1610063257074548737       manisaheb     False       Chandigarh , India
# 4      1610063066976116736       LukeGe669     False         Montréal, Québec
# ...                    ...             ...       ...                      ...
# 15277  1609338749858480134        paulnray     False  ÜT: 51.420708,-0.175979
# 15278  1609338740371066883  CameronCiletti     False                  Online
# 15279  1609338731021860864       archpaper      True                 New York
# 15280  1609338728409092097     George_SLiu     False      Brisbane, Australia
# 15281  1609338691453091841        kobegiwa     False
#
#        Followers                                              Tweet  \
# ...

# %%
df_8.to_csv('Twitter_Jan_11.csv',index=False)

# %%
query = 'ChatGPT since:2023-01-8 until:2023-01-11'
limit = 100000
tweets_9 = []
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets_9) == limit:
        break
    else:
        tweets_9.append([tweet.id, 
                       tweet.user.username, 
                       tweet.user.verified, 
                       tweet.user.location,
                       tweet.user.followersCount,
                       tweet.rawContent, 
                       tweet.date,
                       tweet.retweetedTweet,
                       tweet.lang])
df_9 = pd.DataFrame(tweets_9, columns = ['UserId',
                                     'UserName',
                                     'Verified',
                                     'Location',
                                     'Followers',
                                     'Tweet',
                                     'Timestamp', 
                                     'Retweeted',                                
                                     'Language'])
df_9
# Out:
#                     UserId        UserName  Verified             Location  \
# 0      1612962488999448576  prissmacolor91     False                   🇸🇪
# 1      1612962487745368064    asikomeworld     False
# 2      1612962485098713094      TopengaNFT     False                 .eth
# 3      1612962483723014145    disconcision     False            Ann Arbor
# 4      1612962478505480192  archivedbridge     False                 indy
# ...                    ...             ...       ...                  ...
# 66979  1611875397913698308        ysftpl42     False
# 66980  1611875389609234433  translation_ja     False
# 66981  1611875383690895360     MindMineMao     False  South Carolina, USA
# 66982  1611875360303452165  saadnajeebsaad     False
# 66983  1611875330427424770  ItaliaStartUp_     False
#
#        Followers                                              Tweet  \
# 0            122                   Quién hizo este lineup, ChatGPT?
# ...

# %%
df_9.to_csv('Twitter_Jan_8.csv',index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\DATA_SCIENCE\\Project\\CHATGPT'
